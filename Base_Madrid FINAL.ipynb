# %%
#Importar librerias necesarias
#%pip install funpymodeling
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#Carga desde un archivo .csv sin indice y eliminar filas innecesarias
Madrid=pd.read_csv("listings Madrid.csv")
Madrid
# Out:
#                         id                                               name  \
# 0                    21853                               Bright and airy room
# 1                    24805                             Gran Via Studio Madrid
# 2                    40718  COZY APARTMENT CIBELES-GRAN VIA-PTA DEL SOL-CH...
# 3                    40916                    Holiday Apartment Madrid Center
# 4                    30320                        Great Vacational Apartments
# ...                    ...                                                ...
# 26919  1178424976968116677                            Cozy studio in Chamberí
# 26920  1178428931888574795                                  habitación cálida
# 26921  1178428958237308022                               Alojamiento céntrico
# 26922  1178801297820730122                     Costa Golf Resort by Interhome
# 26923  1178999049049764954                                        Farmacia VI
#
#          host_id                    host_name neighbourhood_group  \
# 0          83531                        Abdel              Latina
# 1      346366726                       Alvaro              Centro
# 2       34217435                         Luis              Centro
# 3         130907                         Dana              Centro
# 4         130907                         Dana              Centro
# ...          ...                          ...                 ...
# 26919  528979463  Digitalización Y Gestión De            Chamberí
# 26920  583336078                 Eudy Yocasta  Puente de Vallecas
# 26921  490492827               Candela Angela            Chamberí
# 26922  185902866   Danielle - Interhome Group   Moncloa - Aravaca
# 26923  438136382                    Home Club              Centro
#
#               neighbourhood   latitude  longitude        room_type  price  \
# 0                  Cármenes  40.403810  -3.741300     Private room   31.0
# 1               Universidad  40.421830  -3.705290  Entire home/apt  104.0
# 2                  Justicia  40.419690  -3.697360  Entire home/apt  114.0
# 3               Universidad  40.422470  -3.705770  Entire home/apt    NaN
# 4                       Sol  40.414760  -3.704180  Entire home/apt    NaN
# ...                     ...        ...        ...              ...    ...
# 26919            Gaztambide  40.433240  -3.712420  Entire home/apt  146.0
# 26920              Numancia  40.398327  -3.654305     Private room   36.0
# 26921              Arapiles  40.432800  -3.710090  Entire home/apt   70.0
# 26922  Ciudad Universitaria  40.464301  -3.749881  Entire home/apt  107.0
# 26923              Justicia  40.423020  -3.700170  Entire home/apt  120.0
#
#        minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0                   4                 33  2018-07-15               0.28
# 1                   5                 43  2024-06-01               0.37
# 2                   2                150  2024-05-30               0.89
# 3                   5                 49  2021-12-11               0.30
# 4                   5                172  2022-09-26               1.01
# ...               ...                ...         ...                ...
# 26919               1                  0         NaN                NaN
# 26920               1                  0         NaN                NaN
# 26921               1                  0         NaN                NaN
# 26922               1                  0         NaN                NaN
# 26923               1                  0         NaN                NaN
#
#        calculated_host_listings_count  availability_365  \
# 0                                   2                83
# 1                                   1               113
# 2                                  15               310
# 3                                   3                 0
# 4                                   3                 0
# ...                               ...               ...
# 26919                               3                46
# 26920                               1               269
# 26921                               1               265
# 26922                               1               273
# 26923                             156               135
#
#        number_of_reviews_ltm     license
# 0                          0         NaN
# 1                         13         NaN
# 2                         20         NaN
# 3                          0         NaN
# 4                          0         NaN
# ...                      ...         ...
# 26919                      0  VT-87689-M
# 26920                      0         NaN
# 26921                      0         NaN
# 26922                      0         NaN
# 26923                      0         NaN
#
# [26924 rows x 18 columns]

# %%
#Identificar valores nulos por columna
Valores_Nulos=Madrid.isnull().sum()
Valores_Nulos
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             4
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                              5304
# minimum_nights                        0
# number_of_reviews                     0
# last_review                        5856
# reviews_per_month                  5856
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                           24182
# dtype: int64

# %%
#Inofrmación tipos de columnas
Tipos_Columnas = Madrid.dtypes
print(Tipos_Columnas)
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                            object
# dtype: object

# %%
#Realizamos una copia del dataframe
copia_Madrid = Madrid.copy()

# %%
#Cuarto método de sustitución de valores nulos
#Sustituir valores nulos por un string en  concreto
copia_Madrid["host_name"]=copia_Madrid["host_name"].fillna("SIN NOMBRE")
copia_Madrid["last_review"]=copia_Madrid["last_review"].fillna("SIN FECHA")
copia_Madrid["license"]=copia_Madrid["license"].fillna("SIN LICENCIA")

# %%
#Primer método de sustitución de valores nulos
#Sustituir valores nulos con promedio o media
copia_Madrid["price"]=copia_Madrid["price"].fillna(round(copia_Madrid ['price'].mean(),1))

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto
copia_Madrid["reviews_per_month"]=copia_Madrid["reviews_per_month"].fillna("0000")

# %%
#Corroboramos valores nulos
valores_nulos=copia_Madrid.isnull().sum()
valores_nulos
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# license                           0
# dtype: int64

# %%
#ELIMINAR OUTLIERS POR EL METODO DE DESVIACION ESTANDAR
copia_Madrid.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                  object
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                            object
# dtype: object

# %%
#Separar por columnas cualitativas y cuantitativas
columnas_cualitativas = copia_Madrid.select_dtypes(include = 'object')
columnas_cuantitativas = copia_Madrid.select_dtypes(include = ['int64', 'float64'])

# %%
#Hacer un boxplot de valores atipicos de las columnas cuantitativas
fig = plt.figure(figsize = (20, 10))
columnas_cuantitativas.plot(kind = 'box', vert = False)
plt.title("Valores atipicos")
plt.show()

# %%
#Identificar los limites superior e inferior
y = columnas_cuantitativas
Limite_superior = y.mean() + 3*y.std()
Limite_inferior = y.mean() - 3*y.std()
print("Limite superior permitido", Limite_superior)
print("Limite inferior permitido", Limite_inferior)
# Out:
# Limite superior permitido id                                1.977067e+18
# host_id                           8.238683e+08
# latitude                          4.049231e+01
# longitude                        -3.610648e+00
# price                             9.414253e+02
# minimum_nights                    9.978497e+01
# number_of_reviews                 2.948332e+02
# calculated_host_listings_count    2.140100e+02
# availability_365                  5.388179e+02
# number_of_reviews_ltm             7.694612e+01
# dtype: float64
# Limite inferior permitido id                               -9.230685e+17
# host_id                          -3.488702e+08
# latitude                          4.035093e+01
# longitude                        -3.777474e+00
# price                            -6.666993e+02
# minimum_nights                   -8.458997e+01
# number_of_reviews                -2.064369e+02
# calculated_host_listings_count   -1.588444e+02
# availability_365                 -2.207970e+02
# number_of_reviews_ltm            -4.934732e+01
# dtype: float64

# %%
#Filtrar solo por columnas dentro de los limites
columnas_cuantitativas_sin_outliers = columnas_cuantitativas[(y <= Limite_superior) & (y >= Limite_inferior)]

# %%
#Revisar valores nulos
valores_nulos_cuantitativo = columnas_cuantitativas_sin_outliers.isnull().sum()
valores_nulos_cuantitativo
# Out:
# id                                   0
# host_id                              0
# latitude                           324
# longitude                          647
# price                              132
# minimum_nights                     171
# number_of_reviews                  674
# calculated_host_listings_count    1099
# availability_365                     0
# number_of_reviews_ltm              552
# dtype: int64

# %%
#Hacer una copia del dataframe y rellenar los valores nulos con la media
columnas_cuantitativas_limpio = columnas_cuantitativas_sin_outliers.copy()
columnas_cuantitativas_limpio = columnas_cuantitativas_limpio.fillna(round(columnas_cuantitativas_sin_outliers.mean(), 1))
columnas_cuantitativas_limpio
# Out:
#                         id    host_id   latitude  longitude  price  \
# 0                    21853      83531  40.403810  -3.741300   31.0
# 1                    24805  346366726  40.421830  -3.705290  104.0
# 2                    40718   34217435  40.419690  -3.697360  114.0
# 3                    40916     130907  40.422470  -3.705770  137.4
# 4                    30320     130907  40.414760  -3.704180  137.4
# ...                    ...        ...        ...        ...    ...
# 26919  1178424976968116677  528979463  40.433240  -3.712420  146.0
# 26920  1178428931888574795  583336078  40.398327  -3.654305   36.0
# 26921  1178428958237308022  490492827  40.432800  -3.710090   70.0
# 26922  1178801297820730122  185902866  40.464301  -3.749881  107.0
# 26923  1178999049049764954  438136382  40.423020  -3.700170  120.0
#
#        minimum_nights  number_of_reviews  calculated_host_listings_count  \
# 0                 4.0               33.0                             2.0
# 1                 5.0               43.0                             1.0
# 2                 2.0              150.0                            15.0
# 3                 5.0               49.0                             3.0
# 4                 5.0              172.0                             3.0
# ...               ...                ...                             ...
# 26919             1.0                0.0                             3.0
# 26920             1.0                0.0                             1.0
# 26921             1.0                0.0                             1.0
# 26922             1.0                0.0                             1.0
# 26923             1.0                0.0                           156.0
#
#        availability_365  number_of_reviews_ltm
# 0                    83                    0.0
# 1                   113                   13.0
# 2                   310                   20.0
# 3                     0                    0.0
# 4                     0                    0.0
# ...                 ...                    ...
# 26919                46                    0.0
# 26920               269                    0.0
# 26921               265                    0.0
# 26922               273                    0.0
# 26923               135                    0.0
#
# [26924 rows x 10 columns]

# %%
#Se juntan las columnas cualitativas con las cuantitativas
Madrid_outliers = pd.concat([columnas_cuantitativas_limpio, columnas_cualitativas], axis = 1)
Madrid_outliers
# Out:
#                         id    host_id   latitude  longitude  price  \
# 0                    21853      83531  40.403810  -3.741300   31.0
# 1                    24805  346366726  40.421830  -3.705290  104.0
# 2                    40718   34217435  40.419690  -3.697360  114.0
# 3                    40916     130907  40.422470  -3.705770  137.4
# 4                    30320     130907  40.414760  -3.704180  137.4
# ...                    ...        ...        ...        ...    ...
# 26919  1178424976968116677  528979463  40.433240  -3.712420  146.0
# 26920  1178428931888574795  583336078  40.398327  -3.654305   36.0
# 26921  1178428958237308022  490492827  40.432800  -3.710090   70.0
# 26922  1178801297820730122  185902866  40.464301  -3.749881  107.0
# 26923  1178999049049764954  438136382  40.423020  -3.700170  120.0
#
#        minimum_nights  number_of_reviews  calculated_host_listings_count  \
# 0                 4.0               33.0                             2.0
# 1                 5.0               43.0                             1.0
# 2                 2.0              150.0                            15.0
# 3                 5.0               49.0                             3.0
# 4                 5.0              172.0                             3.0
# ...               ...                ...                             ...
# 26919             1.0                0.0                             3.0
# 26920             1.0                0.0                             1.0
# 26921             1.0                0.0                             1.0
# 26922             1.0                0.0                             1.0
# 26923             1.0                0.0                           156.0
#
#        availability_365  number_of_reviews_ltm  \
# 0                    83                    0.0
# 1                   113                   13.0
# 2                   310                   20.0
# 3                     0                    0.0
# 4                     0                    0.0
# ...                 ...                    ...
# 26919                46                    0.0
# 26920               269                    0.0
# 26921               265                    0.0
# 26922               273                    0.0
# 26923               135                    0.0
#
#                                                     name  \
# 0                                   Bright and airy room
# 1                                 Gran Via Studio Madrid
# 2      COZY APARTMENT CIBELES-GRAN VIA-PTA DEL SOL-CH...
# 3                        Holiday Apartment Madrid Center
# 4                            Great Vacational Apartments
# ...                                                  ...
# 26919                            Cozy studio in Chamberí
# 26920                                  habitación cálida
# 26921                               Alojamiento céntrico
# 26922                     Costa Golf Resort by Interhome
# 26923                                        Farmacia VI
#
#                          host_name neighbourhood_group         neighbourhood  \
# 0                            Abdel              Latina              Cármenes
# 1                           Alvaro              Centro           Universidad
# 2                             Luis              Centro              Justicia
# 3                             Dana              Centro           Universidad
# 4                             Dana              Centro                   Sol
# ...                            ...                 ...                   ...
# 26919  Digitalización Y Gestión De            Chamberí            Gaztambide
# 26920                 Eudy Yocasta  Puente de Vallecas              Numancia
# 26921               Candela Angela            Chamberí              Arapiles
# 26922   Danielle - Interhome Group   Moncloa - Aravaca  Ciudad Universitaria
# 26923                    Home Club              Centro              Justicia
#
#              room_type last_review reviews_per_month       license
# 0         Private room  2018-07-15              0.28  SIN LICENCIA
# 1      Entire home/apt  2024-06-01              0.37  SIN LICENCIA
# 2      Entire home/apt  2024-05-30              0.89  SIN LICENCIA
# 3      Entire home/apt  2021-12-11               0.3  SIN LICENCIA
# 4      Entire home/apt  2022-09-26              1.01  SIN LICENCIA
# ...                ...         ...               ...           ...
# 26919  Entire home/apt   SIN FECHA              0000    VT-87689-M
# 26920     Private room   SIN FECHA              0000  SIN LICENCIA
# 26921  Entire home/apt   SIN FECHA              0000  SIN LICENCIA
# 26922  Entire home/apt   SIN FECHA              0000  SIN LICENCIA
# 26923  Entire home/apt   SIN FECHA              0000  SIN LICENCIA
#
# [26924 rows x 18 columns]

# %%
#Comprobamos que no existan valores nulos
valores_nulos_Madrid_outliers = Madrid_outliers.isnull().sum()
valores_nulos_Madrid_outliers
# Out:
# id                                0
# host_id                           0
# latitude                          0
# longitude                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# name                              0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# room_type                         0
# last_review                       0
# reviews_per_month                 0
# license                           0
# dtype: int64

# %%
#ANÁLISIS UNIVARIADO A VARIABLES CATEGÓRICAS
#Extraer características de análisis univariado y generar tabla de frecuencias
freq_tbl(Madrid_outliers)
Madrid_outliers.dtypes
# Out:
#                                                     name  frequency  \
# 0                            Habitación con baño privado         33
# 1      H. Individual In Reformed Residence has wifi &...         28
# 2                                   Habitación en Madrid         24
# 3                                     Habitación privada         23
# 4       Fantastic residence ``FUNWAY´´ north zone Madrid         19
# ...                                                  ...        ...
# 25225                         2° A - Apartamento de lujo          1
# 25226              Affordable, Full Service Apartment.2B          1
# 25227                                     Tirso Design I          1
# 25228           plaza españa 18m² bedroom close Gran Via          1
# 25229                                        Farmacia VI          1
#
#        percentage  cumulative_perc
# 0        0.001226         0.001226
# 1        0.001040         0.002266
# 2        0.000891         0.003157
# 3        0.000854         0.004011
# 4        0.000706         0.004717
# ...           ...              ...
# 25225    0.000037         0.999851
# 25226    0.000037         0.999889
# 25227    0.000037         0.999926
# 25228    0.000037         0.999963
# 25229    0.000037         1.000000
#
# [25230 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                        host_name  frequency  percentage  cumulative_perc
# 0                         Javier        347    0.012888         0.012888
# 1                          Jorge        299    0.011105         0.023993
# 2                           Ukio        290    0.010771         0.034765
# 3                      MIT House        289    0.010734         0.045498
# 4            Fran Y Marta Isabel        289    0.010734         0.056232
# ...                          ...        ...         ...              ...
# 4523              Isabel Yolanda          1    0.000037         0.999851
# 4524                     Natasha          1    0.000037         0.999889
# 4525                    Devidass          1    0.000037         0.999926
# 4526                Raul Ernesto          1    0.000037         0.999963
# 4527  Danielle - Interhome Group          1    0.000037         1.000000
#
# [4528 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#       neighbourhood_group  frequency  percentage  cumulative_perc
# 0                  Centro      11294    0.419477         0.419477
# 1                Chamberí       1803    0.066966         0.486443
# 2               Salamanca       1737    0.064515         0.550958
# 3                  Tetuán       1605    0.059612         0.610570
# 4              Arganzuela       1407    0.052258         0.662829
# 5             Carabanchel        991    0.036807         0.699636
# 6                  Retiro        942    0.034987         0.734623
# 7           Ciudad Lineal        926    0.034393         0.769016
# 8               Chamartín        873    0.032425         0.801441
# 9      Puente de Vallecas        824    0.030605         0.832046
# 10                 Latina        775    0.028785         0.860830
# 11      Moncloa - Aravaca        727    0.027002         0.887832
# 12                  Usera        618    0.022953         0.910786
# 13  San Blas - Canillejas        586    0.021765         0.932551
# 14              Hortaleza        533    0.019796         0.952347
# 15  Fuencarral - El Pardo        412    0.015302         0.967650
# 16             Villaverde        261    0.009694         0.977344
# 17                Barajas        196    0.007280         0.984623
# 18              Moratalaz        195    0.007243         0.991866
# 19      Villa de Vallecas        135    0.005014         0.996880
# 20              Vicálvaro         84    0.003120         1.000000
#
# ----------------------------------------------------------------
#
#      neighbourhood  frequency  percentage  cumulative_perc
# 0      Embajadores       3061    0.113690         0.113690
# 1      Universidad       2414    0.089660         0.203350
# 2          Palacio       1931    0.071720         0.275071
# 3              Sol       1449    0.053818         0.328889
# 4         Justicia       1333    0.049510         0.378398
# ..             ...        ...         ...              ...
# 122        Palomas          9    0.000334         0.999331
# 123     Aeropuerto          9    0.000334         0.999666
# 124       El Pardo          4    0.000149         0.999814
# 125  Fuentelareina          4    0.000149         0.999963
# 126        Atalaya          1    0.000037         1.000000
#
# [127 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#          room_type  frequency  percentage  cumulative_perc
# 0  Entire home/apt      17346    0.644258         0.644258
# 1     Private room       9103    0.338100         0.982358
# 2      Shared room        381    0.014151         0.996509
# 3       Hotel room         94    0.003491         1.000000
#
# ----------------------------------------------------------------
#
#      last_review  frequency  percentage  cumulative_perc
# 0      SIN FECHA       5856    0.217501         0.217501
# 1     2024-06-09       1199    0.044533         0.262034
# 2     2024-05-31        899    0.033390         0.295424
# 3     2024-06-02        839    0.031162         0.326586
# 4     2024-06-10        671    0.024922         0.351508
# ...          ...        ...         ...              ...
# 1840  2018-12-07          1    0.000037         0.999851
# 1841  2022-11-10          1    0.000037         0.999889
# 1842  2021-01-06          1    0.000037         0.999926
# 1843  2020-01-18          1    0.000037         0.999963
# 1844  2017-03-19          1    0.000037         1.000000
#
# [1845 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#     reviews_per_month  frequency  percentage  cumulative_perc
# 0                0000       5856    0.217501         0.217501
# 1                 1.0        441    0.016379         0.233881
# 2                0.02        281    0.010437         0.244317
# 3                0.03        246    0.009137         0.253454
# 4                0.09        235    0.008728         0.262182
# ..                ...        ...         ...              ...
# 982              7.75          1    0.000037         0.999851
# 983              9.57          1    0.000037         0.999889
# 984              9.98          1    0.000037         0.999926
# 985              7.19          1    0.000037         0.999963
# 986              11.0          1    0.000037         1.000000
#
# [987 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                    license  frequency  percentage  cumulative_perc
# 0             SIN LICENCIA      24182    0.898158         0.898158
# 1            VT REGISTRADA         62    0.002303         0.900461
# 2                   405007         39    0.001449         0.901909
# 3                       VT         25    0.000929         0.902838
# 4                   AM-336         20    0.000743         0.903580
# ...                    ...        ...         ...              ...
# 2115               VT-7135          1    0.000037         0.999851
# 2116               VT-1643          1    0.000037         0.999889
# 2117  1355309VK4715E0024XU          1    0.000037         0.999926
# 2118               VT-7323          1    0.000037         0.999963
# 2119            VT-87689-M          1    0.000037         1.000000
#
# [2120 rows x 4 columns]
#
# ----------------------------------------------------------------
# id                                  int64
# host_id                             int64
# latitude                          float64
# longitude                         float64
# price                             float64
# minimum_nights                    float64
# number_of_reviews                 float64
# calculated_host_listings_count    float64
# availability_365                    int64
# number_of_reviews_ltm             float64
# name                               object
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# room_type                          object
# last_review                        object
# reviews_per_month                  object
# license                            object
# dtype: object

# %%
tabla1=freq_tbl(Madrid_outliers["neighbourhood_group"])
filtro1=tabla1[tabla1["frequency"]>1]
filtro1_index=filtro1.set_index("neighbourhood_group")
filtro1_index_freq=filtro1_index.drop(["percentage", "cumulative_perc"], axis=1)
filtro1_index_freq.plot(kind="bar", width=.8, figsize=(10,5), color="#fa8762")
plt.ylabel("frecuencia")
plt.title("Grupo de vecindario")
# Out:
# Text(0.5, 1.0, 'Grupo de vecindario')

# %%
tabla2=freq_tbl(Madrid_outliers["neighbourhood"])
filtro2=tabla2[tabla2["frequency"]>250]
filtro2_index=filtro2.set_index("neighbourhood")
filtro2_index_freq=filtro2_index.drop(["percentage", "cumulative_perc"], axis=1)
filtro2_index_freq.plot(kind="bar", width=.8, figsize=(10,5), color="#ebc846")
plt.ylabel("frecuencia")
plt.title("Vecindarios")
# Out:
# Text(0.5, 1.0, 'Vecindarios')

# %%
tabla3=freq_tbl(Madrid_outliers["room_type"])
filtro3=tabla3[tabla3["frequency"]>1]
filtro3_index=filtro3.set_index("room_type")
filtro3_index["frequency"].plot(kind="pie", figsize=(10,5),shadow=True, autopct='%1.1f%%' )
plt.title("Tipo de cuarto")
# Out:
# Text(0.5, 1.0, 'Tipo de cuarto')

# %%
tabla4=freq_tbl(Madrid_outliers["last_review"])
filtro4=tabla4[tabla4["frequency"]>500]
filtro4_index=filtro4.set_index("last_review")
filtro4_index["frequency"].plot(kind="pie", figsize=(10,5),shadow=True, autopct='%1.1f%%' )
plt.title("Fecha de última reseña")
# Out:
# Text(0.5, 1.0, 'Fecha de última reseña')

# %%
tabla5=freq_tbl(Madrid_outliers["reviews_per_month"])
filtro5 = tabla5[(tabla5["frequency"] > 1) & (tabla5["frequency"] < 5000)]
filtro5_index=filtro5.set_index("reviews_per_month")
filtro5_index_freq=filtro5_index.drop(["percentage", "cumulative_perc"], axis=1)
filtro5_index_freq.plot(kind="area", figsize=(10,5), alpha=.6)
plt.title("Reseñas por mes")
# Out:
# Text(0.5, 1.0, 'Reseñas por mes')

# %%
tabla6=freq_tbl(Madrid_outliers["license"])
filtro6 = tabla6[(tabla6["frequency"] > 1) & (tabla5["frequency"] < 5000)]
filtro6_index=filtro6.set_index("license")
filtro6_index_freq=filtro6_index.drop(["percentage", "cumulative_perc"], axis=1)
filtro6_index_freq.plot(kind="area", figsize=(10,5), alpha=.6)
plt.title("Licencia")
# Out:
# Text(0.5, 1.0, 'Licencia')

# %%
tabla7=freq_tbl(Madrid_outliers["name"])
filtro7=tabla7[tabla7["frequency"]>10]
filtro7_index=filtro7.set_index("name")
filtro7_index_freq=filtro7_index.drop(["percentage", "cumulative_perc"], axis=1)
filtro7_index_freq.plot(kind="bar", width=.8, figsize=(10,5), color="#57c112")
plt.ylabel("frecuencia")
plt.title("Nombre del alojamiento")
# Out:
# Text(0.5, 1.0, 'Nombre del alojamiento')

# %%
tabla8=freq_tbl(Madrid_outliers["host_name"])
filtro8=tabla8[tabla8["frequency"]>150]
filtro8_index=filtro8.set_index("host_name")
filtro8_index_freq=filtro8_index.drop(["percentage", "cumulative_perc"], axis=1)
filtro8_index_freq.plot(kind="bar", width=.8, figsize=(10,5), color="#16cfc4")
plt.ylabel("frecuencia")
plt.title("Nombre del host")
# Out:
# Text(0.5, 1.0, 'Nombre del host')

# %%
#Convertir archivo filtrado a CSV
Madrid_outliers.to_csv("Actividad 6 (Evaluación 1-Madrid).csv")

# %%
#Descargar archivo en csv
from google.colab import files
files.download("Actividad 6 (Evaluación 1-Madrid).csv")
